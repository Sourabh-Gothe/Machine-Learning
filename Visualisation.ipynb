# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv(r"https://raw.githubusercontent.com/abulbasar/data/master/insurance.csv")

# %%
plt.hist(np.log1p(df.charges))
# Out:
# (array([  46.,  105.,  101.,  155.,  198.,  283.,  156.,  123.,  115.,   56.]),
#  array([  7.02364666,   7.42758805,   7.83152943,   8.23547082,
#           8.63941221,   9.0433536 ,   9.44729498,   9.85123637,
#          10.25517776,  10.65911914,  11.06306053]),
#  <a list of 10 Patch objects>)

# %%
df.plot.scatter("age", "charges")
